# %%
#solutions

# %%
import pandas as pd
import numpy as np

# %%
# Reading data files into a DataFrame
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
# extracting the files
display("File numner 1")
df1 = pd.DataFrame(file1)
display(df1)
df1.shape

display("File numner 2")
df2 = pd.DataFrame(file2)
display(df2)
df2.shape

display("File numner 3")
df3 = pd.DataFrame(file3)
display(df3)
df3.shape
# Out:
# 'File numner 1'
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#rearranging coloumns
#i want to first exctract the names of the coloumsn in order to do that

#display.max_columns(df1)
file1_coloumns = file1.columns
display(file1_coloumns)

file1_coloumns2 = file2.columns
display(file1_coloumns2)
file1_coloumns3 = file3.columns
display(file1_coloumns3)

#length of each file
print (df1.shape)
print (df2.shape)
print (df3.shape)
# the couloumns are of same length
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
# reorder them all
# the final result i wish [customer],[state],[gender],[education], [income], [customer lifetime value][vehicel class], [policy type][monthly premium auto],[number of open complaint policy type][total clain amaount]

df1 = df1[['Customer', 'ST', 'GENDER', 'Education','Income','Customer Lifetime Value','Vehicle Class','Policy Type','Monthly Premium Auto','Number of Open Complaints','Total Claim Amount']]
df1

df2 = df2[['Customer', 'ST', 'GENDER', 'Education','Income','Customer Lifetime Value','Vehicle Class','Policy Type','Monthly Premium Auto','Number of Open Complaints','Total Claim Amount']]
df2

df3 = df3[['Customer', 'State', 'Gender', 'Education','Income','Customer Lifetime Value','Vehicle Class','Policy Type','Monthly Premium Auto','Number of Open Complaints','Total Claim Amount']]
df3

#renaming files1 and 2 and replacing ST with state
#df1 = df1.rename(coloumns = {'ST':'state'})
 
df1 = df1.rename(columns={"ST": "State"})
df1

df2 = df2.rename(columns={"ST": "State"})
df2
# Out:
#     Customer       State GENDER Education  Income Customer Lifetime Value  \
# 0    GS98873     Arizona      F  Bachelor   16061              323912.47%
# 1    CW49887  California      F    Master   79487              462680.11%
# 2    MY31220  California      F   College   54230              899704.02%
# 3    UH35128      Oregon      F   College   71210             2580706.30%
# 4    WH52799     Arizona      F   College   94903              380812.21%
# ..       ...         ...    ...       ...     ...                     ...
# 991  HV85198     Arizona      M    Master   63513              847141.75%
# 992  BS91566     Arizona      F   College   58161              543121.91%
# 993  IL40123      Nevada      F   College   83640              568964.41%
# 994  MY32149  California      F    Master       0              368672.38%
# 995  SA91515  California      M  Bachelor       0              399258.39%
#
#      Vehicle Class     Policy Type  Monthly Premium Auto  \
# ...

# %%
# convert everything to lower case for easy cleaning before re-uploading to the file
cols = []
for i in range(len(df1.columns)):
    cols.append(df1.columns[i].lower())
df1.columns = cols
df2.columns = cols
df3.columns = cols
display(cols)

df1
df2
df3
# Out:
# ['customer',
#  'state',
#  'gender',
#  'education',
#  'income',
#  'customer lifetime value',
#  'vehicle class',
#  'policy type',
#  'monthly premium auto',
#  'number of open complaints',
#  'total claim amount']
#      customer       state gender             education  income  \
# 0     SA25987  Washington      M  High School or Below       0
# 1     TB86706     Arizona      M                Master       0
# 2     ZL73902      Nevada      F              Bachelor   25820
# 3     KX23516  California      F  High School or Below       0
# 4     FN77294  California      M  High School or Below   30366
# ...       ...         ...    ...                   ...     ...
# 7065  LA72316  California      M              Bachelor   71941
# 7066  PK87824  California      F               College   21604
# 7067  TD14365  California      M              Bachelor       0
# 7068  UP19263  California      M               College   21941
# ...

# %%
# now to blend them togther i would use concat methos

data = pd.concat([df1,df2,df3], axis=0) #discuss axis here
print(data.shape)

#display(data)
# Out:
# (12074, 11)

# %%
display(data.iloc[:10])

#check if the colomns are stting for categorical and integer for numerical --> input needed
#for i in range(data.iloc[:12]):
#    if (data.iloc[:, i].dtype != np.number
#        print(data.column[i],'is a categorical Field')
#    else:
#        print('the coloumn',cols[i],'is a numericalField')
    
        
        
#for column in file3.columns:
#    file3_lowercase.append(column.lower())
#file3.columns = file3_lowercase
#print(file3.columns)
# Out:
#   customer       state gender             education   income  \
# 0  RB50392  Washington    NaN                Master      0.0
# 1  QZ44356     Arizona      F              Bachelor      0.0
# 2  AI49188      Nevada      F              Bachelor  48767.0
# 3  WW63253  California      M              Bachelor      0.0
# 4  GA49547  Washington      M  High School or Below  36357.0
# 5  OC83172      Oregon      F              Bachelor  62902.0
# 6  XZ87318      Oregon      F               College  55350.0
# 7  CF85061     Arizona      M                Master      0.0
# 8  DY87989      Oregon      M              Bachelor  14072.0
# 9  BQ94931      Oregon      F               College  28812.0
#
#   customer lifetime value  vehicle class     policy type  \
# 0                     NaN  Four-Door Car   Personal Auto
# 1              697953.59%  Four-Door Car   Personal Auto
# 2             1288743.17%   Two-Door Car   Personal Auto
# 3              764586.18%            SUV  Corporate Auto
# ...

# %%
# categorical coloumns
#gender
#education
#vehicle class
# policy type


# numerical couloumns
#customer
#income
#customer lifetime value
# monthly premium auto
# number of open complaints
# total claim amount


# check if all the coulomns have uniques values
#list(data.head())
#data.head()
#list(data.tail())

#data_coloumns_list = []
#nunique_data_coloumns = {}
#for i in range(len(df1.columns)):
#    print(i)
    #data_coloumns_list.append(df1.columns[i])
#    nunique_data_coloumns.append(list(data.coloumns[i].unique()))
#data_coloumns_list    
    
### Important ###
### I tried to append the dict using for loop for all the unique values in every coloumn but failed #:(
## so now i manually made the list of unique values
display(list(data['gender'].unique()))
display(data[data['gender'].isna()==True]) # checking rows that are null based on a specific column
display(data['gender'].nunique())
# alternative
print("using ISNA")
display(data.isna().sum())
print(data.shape)
# Out:
# [nan, 'F', 'M', 'Femal', 'Male', 'female']
#     customer       state gender             education   income  \
# 0    RB50392  Washington    NaN                Master      0.0
# 11   VQ65197  California    NaN               College      0.0
# 12   DP39365  California    NaN                Master  77026.0
# 13   SJ95423     Arizona    NaN  High School or Below  99845.0
# 14   IL66569  California    NaN               College  83689.0
# ..       ...         ...    ...                   ...      ...
# 167  DH41343  Washington    NaN               College  92834.0
# 228  AO98601  Washington    NaN              Bachelor  54500.0
# 257  XR95069  Washington    NaN              Bachelor  29834.0
# 372  HF88410  Washington    NaN  High School or Below  36765.0
# 980  SV62436  Washington    NaN              Bachelor  13789.0
#
#     customer lifetime value  vehicle class     policy type  \
# 0                       NaN  Four-Door Car   Personal Auto
# ...

# %%
#Delete the column education and the number of open complaints from the dataframe.

data = data.drop("education", axis=1)
# alternative
data = data.drop(columns="number of open complaints")
display(data)
# Out:
#      customer       state gender   income customer lifetime value  \
# 0     RB50392  Washington    NaN      0.0                     NaN
# 1     QZ44356     Arizona      F      0.0              697953.59%
# 2     AI49188      Nevada      F  48767.0             1288743.17%
# 3     WW63253  California      M      0.0              764586.18%
# 4     GA49547  Washington      M  36357.0              536307.65%
# ...       ...         ...    ...      ...                     ...
# 7065  LA72316  California      M  71941.0             23405.98798
# 7066  PK87824  California      F  21604.0             3096.511217
# 7067  TD14365  California      M      0.0             8163.890428
# 7068  UP19263  California      M  21941.0             7524.442436
# 7069  Y167826  California      M      0.0             2611.836866
#
#       vehicle class     policy type  monthly premium auto  total claim amount
# 0     Four-Door Car   Personal Auto                1000.0            2.704934
# ...

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
data["customer lifetime value"].head(20) 

# I neeed help Here !! please help!!
# Out:
# 0             NaN
# 1      697953.59%
# 2     1288743.17%
# 3      764586.18%
# 4      536307.65%
# 5      825629.78%
# 6      538089.86%
# 7      721610.03%
# 8     2412750.40%
# 9      738817.81%
# 10     473899.20%
# 11     819719.71%
# 12     879879.70%
# 13     881901.89%
# 14     538443.17%
# 15     746313.94%
# 16     256686.78%
# 17     394524.16%
# 18     571033.31%
# 19     816261.71%
# Name: customer lifetime value, dtype: object

# %%
# the duplicates
duplicates = data[data.duplicated()]
duplicates
# Out:
#      customer       state gender   income customer lifetime value  \
# 1072      NaN         NaN    NaN      NaN                     NaN
# 1073      NaN         NaN    NaN      NaN                     NaN
# 1074      NaN         NaN    NaN      NaN                     NaN
# 1075      NaN         NaN    NaN      NaN                     NaN
# 1076      NaN         NaN    NaN      NaN                     NaN
# ...       ...         ...    ...      ...                     ...
# 4006      NaN         NaN    NaN      NaN                     NaN
# 4007      NaN         NaN    NaN      NaN                     NaN
# 0     GS98873     Arizona      F  16061.0              323912.47%
# 1     CW49887  California      F  79487.0              462680.11%
# 2     MY31220  California      F  54230.0              899704.02%
#
#       vehicle class    policy type  monthly premium auto  total claim amount
# 1072            NaN            NaN                   NaN                 NaN
# ...

# %%
# keeping the last one from the duplicates
#lentgh before dropping and deleting duplcates
print('before')
display(data.shape)

duplicate_keep_last = data[data.duplicated(keep = 'last')]
print(duplicate_keep_last)
print('during')
data.shape
display(duplicate_keep_last.drop_duplicates())


display(data.drop_duplicates())
print('after')
data.shape

# seems like i need help here!!
# Out:
# before
# (12074, 9)
#      customer       state gender   income customer lifetime value  \
# 1068  GS98873     Arizona      F  16061.0              323912.47%
# 1069  CW49887  California      F  79487.0              462680.11%
# 1070  MY31220  California      F  54230.0              899704.02%
# 1071      NaN         NaN    NaN      NaN                     NaN
# 1072      NaN         NaN    NaN      NaN                     NaN
# ...       ...         ...    ...      ...                     ...
# 4002      NaN         NaN    NaN      NaN                     NaN
# 4003      NaN         NaN    NaN      NaN                     NaN
# 4004      NaN         NaN    NaN      NaN                     NaN
# 4005      NaN         NaN    NaN      NaN                     NaN
# 4006      NaN         NaN    NaN      NaN                     NaN
#
#       vehicle class    policy type  monthly premium auto  total claim amount
# ...

# %%
# drop all the NaN
data.value_counts(dropna=True) 
data
